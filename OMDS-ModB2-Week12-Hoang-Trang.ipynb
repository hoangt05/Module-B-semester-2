# %% [markdown]
# # Week 12 - Milestone Two week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone Two is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you plot the number visitors to a museum over the seven days of a week; then again the following week.  Can you suggest the advantages and disadvantages of the following two ways of presenting the data?

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
time_series_0 = np.array([100, 110, 130, 120, 100, 90, 80])
time_series_1 = np.array([70, 90, 100, 100, 120, 110, 90])
fig, axs = plt.subplots(1, 2)
axs[0].plot(time_series_0)
axs[1].plot(time_series_1)
plt.subplots_adjust(wspace = 0)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %%
plt.plot(time_series_0)
plt.plot(time_series_1)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %% [markdown]
# # Side-By-Side Plot
#
# **Advantage**
# * Easier to read individually as there are no overlaps
#
# **Disadvantage**
# * Harder to compare the number of visitors between the two weeks
# * We have to visually switch between the two plots constantly if we wanted to compare them
#
# # Combined Plot
#
# **Advantage**
# * Make week to week easier to compare by highlighting the differences across days
#
# **Disadvantage**
# * Can be visually cluttering
# * If one week performs way better, then scaling could be off

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone Two rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 187-205 of the Storytelling With Data book as best you can. (Chapter Eight). You do not have to get the exact data values right, just the overall look and feel.

# %%
years = [2019, 2019]
prices = [400, 380]
products = ['A', 'B']

plt.figure(figsize=(6, 4))
plt.scatter(years, prices, color='navy', s=28) 

for i, label in enumerate(products):
    plt.text(years[i] + 0.07, prices[i], label, va='center', fontsize=8)

plt.xlim(2018, 2025)
plt.ylim(0, 500)
plt.yticks(range(0, 501, 100), [f'${y}' for y in range(0, 501, 100)])
plt.xticks(range(2019, 2026))

plt.xlabel('Year')
plt.ylabel('Average price')
plt.title('Retail price over time', loc='left')

plt.suptitle('Products A and B were launched in 2019 at price points of $360+', 
             x=0.0, ha='left', fontsize=12, color='navy')
plt.subplots_adjust(top=0.85)

for spine in ['top', 'right']:
    plt.gca().spines[spine].set_visible(False)

plt.show()
